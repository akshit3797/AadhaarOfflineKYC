# %%
from zipfile import ZipFile
import xml.etree.ElementTree as ET
import base64
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import hashlib

# %%
with ZipFile ('offlineaadhaar20191122041707173.zip','r') as zipObj:
    pwd = '3797'.encode('ascii')
    zipObj.extractall('temp',pwd = pwd)

# %%
tree = ET.parse('temp/offlineaadhaar20191122041707173.xml')
root = tree.getroot()

# %% [markdown]
# ## Attributes

# %%
root[0][0].keys()
# Out:
# ['dob', 'e', 'gender', 'm', 'name']

# %% [markdown]
# ## Name

# %%
root[0][0].attrib['name']
# Out:
# 'Akshit Mittal'

# %% [markdown]
# ## Gender

# %%
root[0][0].attrib['gender']
# Out:
# 'M'

# %% [markdown]
# ## DOB

# %%
root[0][0].attrib['dob']
# Out:
# '03-07-1997'

# %% [markdown]
# ## Address

# %%
for i in root[0][1].keys():
    print(i + ' : ' + root[0][1].attrib[i])
# Out:
# careof : S/O Rajesh Kumar Mittal
# country : India
# dist : Baleswar
# house : BALGOPALPUR
# landmark : EMAMI PAPER MILLS
# loc : BALASORE
# pc : 756020
# po : Rasaslpur
# state : Odisha
# street : PO-RASALPUR
# subdist : Remuna
# vtc : Rasalpur

# %% [markdown]
# ## Image

# %%
imagestr = root[0][2].text
with open("imageToSave.jpg","wb") as fh:
    fh.write(base64.b64decode(imagestr))
    
img = mpimg.imread('imageToSave.jpg',format='JPG')
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Last 4 digit

# %%
last_digit = int(root.attrib['referenceId'][:4][-1])
root.attrib['referenceId'][:4]
# Out:
# '7781'

# %% [markdown]
# ## Mobile Number

# %%
phone_number = '9438855607'
share_code = '3797'
phone_reqd = phone_number + share_code

for i in range (last_digit):
    result = hashlib.sha256(phone_reqd.encode())
    print(result.hexdigest())
# Out:
# 4d6663fa1fe103849286e2f38b9dec7f2aa48bb632ef0dda2d441130fb89a093

# %%
root[0][0].attrib['m']
# Out:
# '4d6663fa1fe103849286e2f38b9dec7f2aa48bb632ef0dda2d441130fb89a093'

# %% [markdown]
# ## Email Address

# %%
emailid = 'smittal3797@gmail.com'
share_code = '3797'
email_reqd = emailid + share_code

for i in range (last_digit):
    result = hashlib.sha256(email_reqd.encode())
    print(result.hexdigest())
# Out:
# 7de5f14adc8e2fb7a231cd01d7a33f97c98d331f040b26c61528b6273b21cbb5

# %% [markdown]
# ## Digital Signature Verification

# %%
root[1][1].text

# %%
for item in root:
    for child in item:
        print(child.tag)

# %%
import base64

# %%
certificate = open('uidai_offline_publickey_19062019.cer','rb')

# %%
certificate_read = certificate.read()

# %%
certificate_encode = base64.encodebytes(certificate_read)

# %%
certificate_encode

# %%
# !pip install pycrypto --user

# %%
import Crypto
from Crypto.PublicKey import RSA
from Crypto import Random

# %%
certificate_encode.verify()
